# %% [markdown]
# # dobot notes
#
# dobot maximum reach: 320mm
#
# ![image.png](attachment:image.png)
#
# - [some guide](https://github.com/SERLatBTH/StarterGuide-Dobot-Magician-with-Python) on the python api

# %% [markdown]
# ## things we don't understand
#
# - is there no constant frame of reference between power cycles?
# - we must convert from camera coordinates to dobot coordinates. what is the dobot coordinate system?
